# %% [markdown]
# # Genetic algorithms using `numpy`

# %% [markdown]
# In this demonstration, we will code up step-by-step, a simple GA for optimizing a trivial function with constraints. Further exploration in this example would be very useful for your project.

# %%
import numpy as np

# Do some Ipython black magic
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %% [markdown]
# ## Problem statement
#
# We need to maximize the function  $ f(\mathbf{x}) = \sum_{i=1}^{6} w_i x_i $ for a given set of weights $ w_i $, with the constraints that $ x_i \; \in \; [-4,4] \; \forall \; i$. This means that the domain $\mathbb{D}$ of the search is $ \mathbb{D}:= [-4,4]^6$. The optimization problem can be succinctly represented as $\left(\mathbb{D}, \mathbb{R} , \mathbf{f}, \geq \right)$.

# %% [markdown]
# ## Ease of solving the problem
#
# We note that this example is trivial because given a set of weights, we need to pick either $x_i=-4$ or $x_i=4$ as the objective function is linear. That's precisely the point however, as we know the solution to the problem, and we can compare how GA performs (as a search algorithm in itself, and against design parameters)

# %% [markdown]
# ## Given
# The weight vector $\mathbf{w} = [6,8,-6,3,3,-4]$. For this case then, the optimal solution is $\mathbf{x}^* = [4, 4, -4, 4, 4, -4]$ which gives a maximum possible objective value $f^* = 120$

# %%
N_WEIGHTS = 6 # Helper variable
WEIGHTS = np.array([6,8,-6,3,3,-4], dtype = np.float64) # Optional dtype argument

# %%
# Confirm the shape so that we are happy
np.shape(WEIGHTS)
# Out:
# (6,)

# %% [markdown]
# #  Representation

# %% [markdown]
# How do you want to encode this problem? To keep the demonstration simple, we pick a set of 6 floating point numbers (as a `numpy` array) directly. We need to keep in mind that variation needs to be done on this representation.

# %%
# I can define my optimal solution vector now, since I have decided my representation
X_STAR = np.array([4, 4, -4, 4, 4, -4], dtype = np.float64)

# %% [markdown]
# Now that we have picked representation, let's start off the problem. We need to pick a population size (i.e. number of parents in the initial generation). Let's pick a nice number, say 10

# %%
# Size of the population
POP_SIZE = 10

# %% [markdown]
# Remember! Each member of this population is a vector with shape `(6,)`. Is there a way to efficiently represent/generate/work with this entire population all at one go?
#
# Of course! Put them together as a 2 dimensional array!

# %%
# Helper variable that generates POP_SIZE x NUM_WEIGHTS population
DOFS_IN_POP = (POP_SIZE, N_WEIGHTS)

# %% [markdown]
# The population will have `POP_SIZE` chromosomes where each chromosome has `NUM_WEIGHTS` genes. Let's generate the initial population that our GA algorithm will work on. This population needs to be randomly initialized, say around $0.0$. The `numpy.random` module comes to mind

# %%
curr_population = np.random.uniform(low=-4.0, high=4.0, size=DOFS_IN_POP)
# What about these guys?
# curr_population = np.random.uniform?
# curr_population = np.random.random_sample?

# %%
curr_population
# Out:
# array([[ 1.88763514, -2.67121433,  0.53267719, -2.97075372, -2.45036077,
#          0.82030131],
#        [ 1.91231625,  0.05983223, -0.50689917,  2.78646532,  0.33842462,
#         -3.603512  ],
#        [ 3.47909899,  3.757548  , -3.05425909, -2.83095443,  3.41985682,
#          3.6210893 ],
#        [ 1.54467246,  2.49041854, -3.60489863,  0.4062219 ,  0.15597427,
#          2.30206468],
#        [ 0.46533454,  2.41594209,  0.04297437,  2.44544608, -3.37450302,
#         -0.21053849],
#        [ 0.42181107,  0.76769273,  0.95160062, -3.12900364, -3.6037452 ,
#          2.91339714],
#        [ 2.56304544, -0.33226296, -0.71533576, -2.90685786, -3.82616072,
#         -2.0560268 ],
#        [-2.57532867, -2.37799439, -0.18565333,  2.38617755,  1.84073031,
#         -1.76661509],
#        [-3.31068529,  0.98081746, -0.20094242,  3.0737728 , -2.01535172,
#         -0.69298644],
#        [-3.08516982,  1.6246642 , -3.92401418,  0.61102454,  2.12192114,
#         -3.10469033]])

# %% [markdown]
# # Fitness assignment
# In this demo, we assign fitness directly using the objective function (without penalty, we'll deal with constraints later on). However you can best decide what fitness works for your problem (competitive? informal?...)

# %%
def calc_fitness(t_pop):
    """ Calculates fitness given the population using global weights
    The fitness function calulates the sum of products between each input and its corresponding weight.
    Returns a (POP_SIZE, ) numpy array
    """        
    # Do elementwise across columns, then sum the columns up together
    # fitness = np.sum(t_pop * WEIGHTS, axis=1)

    # Do a matrix vector multiply of (10,6) * (6,)
    fitness = t_pop @ WEIGHTS

    # There are other ways to do the same thing, but why would you?
    return fitness

# %%
my_fitness = calc_fitness(curr_population)
print(my_fitness.shape)
print(my_fitness)
# Out:
# (10,)
# [-32.78451566  38.78266823  56.54288246  43.29910463  19.91668086
#  -28.88903058   5.03723498 -13.61482319  -4.86470855  38.6479782 ]

# %% [markdown]
# # Selection for variation
#
# ### How do you select parents to spread their genes?
# One way to do it is to select *best* parents only to mate. This is an example of a **determinstic selection scheme**, wherein we rank them by fitness and consider the best ones.
#
# ### How many parents to select for mating?
# This is up to the user. Some people prefer to use heuristics based on the population size for determining the mating pool size. Sometimes it depends on the selection scheme used (for example, in tournament selection where the $T$ parameter, along with the population size determines the mating pool size).
#
# For simplicity in this demo, let's fix the number of parents that are selected to mate at every iteration and store it as a variable.

# %%
#SELECTING THE BEST FOUR AND SORTING ACCORDINGLY

N_MATING = 4

def select_determinstic(t_pop, t_fitness):
    """ Given current population t_pop, select N_MATING number of parents using determinstic selection scheme
    based on t_fitness 

    Returns parents and their fitness (just because)
    """
    # Returns sorting indices, based on max fitness
    # Arranged from min-> max fitness
    idx = np.argsort(t_fitness)
    # Now its max fitness on top and min on bottom
    idx = idx[::-1]

    # Sort parents according to the index
    parents = t_pop[idx]

    # Select best parents
    parents = parents[:N_MATING, :]
    return (parents, calc_fitness(parents))

    
    ''' If you don't want to reverse, you can do the following
    '''
#     # Returns sorting indices, based on max fitness
#     # Arranged from min-> max fitness
#     idx = np.argsort(t_fitness)

#     # Select parents according to the index
#     parents = t_pop[idx]

#     # Select best parents
#     parents = parents[-N_MATING:, :]
#     return (parents, calc_fitness(parents))

    
    '''You can also do it in a convoluted way like below, but I don't recommend it
    Always code like some other person is watching you code''' 

#     # Selecting the best individuals in the current generation as parents for producing the offspring of the next generation.
#     parents = numpy.empty((num_parents, pop.shape[1]))
#     for parent_num in range(num_parents):
#         max_fitness_idx = numpy.where(fitness == numpy.max(fitness))
#         max_fitness_idx = max_fitness_idx[0][0]
#         parents[parent_num, :] = pop[max_fitness_idx, :]
#         fitness[max_fitness_idx] = -99999999999
#     return parents

# %%
my_parents, my_par_fitness = select_determinstic(curr_population, my_fitness)
my_parents
my_par_fitness
# Out:
# array([[ 3.47909899,  3.757548  , -3.05425909, -2.83095443,  3.41985682,
#          3.6210893 ],
#        [ 1.54467246,  2.49041854, -3.60489863,  0.4062219 ,  0.15597427,
#          2.30206468],
#        [ 1.91231625,  0.05983223, -0.50689917,  2.78646532,  0.33842462,
#         -3.603512  ],
#        [-3.08516982,  1.6246642 , -3.92401418,  0.61102454,  2.12192114,
#         -3.10469033]])
# array([56.54288246, 43.29910463, 38.78266823, 38.6479782 ])

# %% [markdown]
# ### Can you show me an example of stochastic selection?
#
# Let's implement Stochastic Universal Sampling, which consists of
#
# * Sampling rate assignment
# * Sampling

# %%
#ANOTHER METHOD OF SELECTING BEST

def select_stochastic(t_pop, t_fitness):
    """ Given current population t_pop, select N_MATING number of parents using SUS
    based on t_fitness 

    Returns parents and their fitness (just because)
    """

    ''' Sampling rate assignment using linear rank-based sampling
    '''
    # Rank based on max fitness
    # Arranged from min-> max fitness
    # Do the same for parents later on
    idx = np.argsort(t_fitness)

    # Copied shamelessly from https://stackoverflow.com/a/5284703
    r_i = np.empty_like(idx)
    r_i[idx] = np.arange(len(t_fitness))
 
    # Same as 
    # r_i = np.argsort(idx)

    """
        >>> t_fitness
        >>> array([-18.29817097,  22.688013  ,  65.55614464, -22.39372802,
           -11.53236791,  40.55497738, -13.77672983,  14.9189356 ,
            60.09509336,  32.67900684])

        >>> idx
        >>> [3 0 6 4 7 1 9 5 8 2]

        >>> r_i
        >>> [1 5 9 0 3 7 2 4 8 6]
    """

    # Calculate linear weighting with alpha = 2
    p_i = r_i + 2

    # Calculate q_i as an avverage measure of p_i
    sum_pi = np.sum(p_i)
    q_i = p_i / sum_pi

    # Rank from biggest to least for ease of use
    q_idx = np.argsort(q_i)

    # Regular q_i is for t_pop
    # The sorted q_i is now for (t_pop)[q_idx]
    # The reversed q_i is then for ((t_pop)[q_idx])[::-1]
    
    q_i = q_i[q_idx]
    q_i = q_i[::-1]


    ''' With this sampling rate q_i pick up four parents
    '''
    # Increment to generated random number
    random_increment = 1./N_MATING

    # Generate a random number
    random_val = np.random.rand(1, )

    # Select four zones of q_i to select
    arrow_locations = random_val + random_increment * np.arange(N_MATING)
    """    
        >>> arrow_locations
        >>> [0.52196859 0.77196859 1.02196859 1.27196859]
    """
    
    # Ensure it stays within 1
    arrow_locations %= 1
    """    
        >>> arrow_locations
        >>> [0.52196859 0.77196859 0.02196859 0.27196859]
    """

    # In place sorting to get (r, r+1/N_MATING, r + 2/N_MATING ...., r + (N_MATING-1)/N_MATING)
    arrow_locations.sort()
    """    
        >>> arrow_locations
        >>> [0.02196859 0.27196859 0.52196859 0.77196859]
    """

    # Based on arrow locations, pick the parents
    cum_qi = np.cumsum(q_i)
    """    
        >>> cum_qi
        >>> [0.16923077 0.32307692 0.46153846 0.58461538 0.69230769 0.78461538
     0.86153846 0.92307692 0.96923077 1.        ]
    """
    
    # Where do you find the arrows within cum_qi
    zone_belong = np.searchsorted(cum_qi, arrow_locations)
    # print(zone_belong)
    """    
        >>> zone_belong
        >>> [0 1 3 5]
    """

    # zone_belong returns index of individuals in the max-->min list 
    # I want indices in the min--> max list
    # One hacky way of doing this is just do a size-1 subtraction
    zone_belong = POP_SIZE - zone_belong - 1
    
    # The q_i of the selected indviduals
    parents = t_pop[q_idx][zone_belong]
    par_fitness = t_fitness[q_idx][zone_belong]

    return (parents, par_fitness)

# %%
my_parents, my_par_fitness = select_stochastic(curr_population, my_fitness)
my_parents
my_par_fitness
# Out:
# array([[ 3.47909899,  3.757548  , -3.05425909, -2.83095443,  3.41985682,
#          3.6210893 ],
#        [ 1.54467246,  2.49041854, -3.60489863,  0.4062219 ,  0.15597427,
#          2.30206468],
#        [-3.08516982,  1.6246642 , -3.92401418,  0.61102454,  2.12192114,
#         -3.10469033],
#        [ 2.56304544, -0.33226296, -0.71533576, -2.90685786, -3.82616072,
#         -2.0560268 ]])
# array([56.54288246, 43.29910463, 38.6479782 ,  5.03723498])

# %% [markdown]
# # Variation
# Variation has two operations : crossover/recombination (produce new offspring from the parents selected in the prior step) and mutation (produced mutated/randomly offset offspring). Let's see each one separately.
#
# ### Recombination
# For this demonstration, lets do a one-point crossover. This means we naively *mix* the solution vectors---we take some  components (among the six) from one parent and the rest from another parent...
#
# Before proceeding, we want to determine the limit of offspring vectors to be produced. This has to be a reasonable number and should depend on the population and the number of parents selected for mating. This also corresponds to the $\lambda$ deterministic selection schemes.
#
# We also need to select $p_c$, the crossover rate---it determines the probability of a crossover happening between two parents.

# %%
N_OFFSPRING = 3
IDX_CROSSOVER = 3

# %% [markdown]
# In our demo, let's fix $p_c$ to 1 (recombination happens always). We also fixed the offspring size above to $0.5 \cdot {\text{N_MATING}\choose 2} = 3$. This allows every selected parent to propogate their genes. The parent vectors are chosen in a fixed fashion (1 mates with 2, 2 with 3 and so on...)

# %% [markdown]
# Where to crossover? Sometimes we use an additional random integer (respecting array range constraints) that determines at which location a crossover should occur. In our example below, let's perform a *uniform* one-point crossover (uniform in the sense that we always do crossover at a selected index)

# %%
#MANY DIFFERENT WAYS TO CROSSOVER, PRODUCES 3 OFFSPRINGS

def crossover(t_parents):
    """ Given a set of parents, combine them and return offspring vectors
    
    Returns the offsprings and their fitness
    """
    
    # Create an emppty vector
    offspring = np.empty((N_OFFSPRING, N_WEIGHTS))

    for k in range(N_OFFSPRING):
        # We do % N_MATING in case it goes out of range
        
        # Index of the first parent to mate.
        p1_idx = k%N_MATING

        # Index of the second parent to mate.
        p2_idx = (k+1)%N_MATING
        
        # The new offspring will have its first half of its genes taken from the first parent.
        offspring[k, :IDX_CROSSOVER] = t_parents[p1_idx, :IDX_CROSSOVER]

        # The new offspring will have its second half of its genes taken from the second parent.
        offspring[k, IDX_CROSSOVER:] = t_parents[p2_idx, IDX_CROSSOVER:]

    return (offspring, calc_fitness(offspring))

# %% [markdown]
# Does crossover create new offspring?

# %%
my_offspring,  my_offspring_fitness = crossover(my_parents)
my_parents
my_offspring
# Out:
# array([[ 3.47909899,  3.757548  , -3.05425909, -2.83095443,  3.41985682,
#          3.6210893 ],
#        [ 1.54467246,  2.49041854, -3.60489863,  0.4062219 ,  0.15597427,
#          2.30206468],
#        [-3.08516982,  1.6246642 , -3.92401418,  0.61102454,  2.12192114,
#         -3.10469033],
#        [ 2.56304544, -0.33226296, -0.71533576, -2.90685786, -3.82616072,
#         -2.0560268 ]])
# array([[ 3.47909899,  3.757548  , -3.05425909,  0.4062219 ,  0.15597427,
#          2.30206468],
#        [ 1.54467246,  2.49041854, -3.60489863,  0.61102454,  2.12192114,
#         -3.10469033],
#        [-3.08516982,  1.6246642 , -3.92401418, -2.90685786, -3.82616072,
#         -2.0560268 ]])

# %% [markdown]
# It does! Are the offsprings fitter than their parents?

# %%
my_par_fitness
my_offspring_fitness
# Out:
# array([56.54288246, 43.29910463, 38.6479782 ,  5.03723498])
# array([61.73886227, 71.43837321,  6.0554313 ])

# %% [markdown]
# They are! This is good news...

# %% [markdown]
# ### Mutation
# For this demonstration, lets add uniform random numbers drawn between $[-0.5, 0.5)$ to the offspring. But let's not do it everytime---we will do that with a probability $p_m = 0.5$, sampled for each offspring. Recollect that this is the mutation rate parameter.

# %%
#MUTATING BY ADDING [-0.5,0.5] TO ONE OR TWO OR MORE AMOUNT OF OFFSPRINGS

PM = 0.5
def mutation(t_offspring):
    """ Given a set of offsprings, introduce mutation in them
   
    Returns the mutated offsprings and their fitness
    """

    # Mutation changes all genes in each offspring randomly.
    # You can also code for a single gene, single gene with some probability and so on...

    # Generate a random number in [0, 1) to mutate each offspring
    random_mutator = np.random.uniform(0.0, 1.0, (N_OFFSPRING,))

    # Check where the random_mutator is > PM
    # Gives true in those places
    idx = random_mutator > PM

    # Count number of trues in the above condition
    nnz = np.count_nonzero(idx)

    # Copy just for comparison of offspring before and after mutation
    # You can remove if efficiency is a concern
    mutated_offspring = t_offspring.copy()

    # For true idx, add randomly sampled vector in [-0.5, 0.5)
    # print(random_mutator, idx)
    mutated_offspring[idx] += np.random.uniform(-0.5, 0.5, (nnz, N_WEIGHTS))
    

    # You can also do this
    """
    coin_toss = np.random.uniform(low=0.0, high=1.0, size=t_offspring.shape)
    idx = coin_toss < PM
    # print(idx)
    random_values = np.random.uniform(low=-0.5, high=0.5, size=idx.shape)
    mutated_offspring = t_offspring + random_values * idx
    """
    
    return (mutated_offspring, calc_fitness(mutated_offspring))

# %% [markdown]
# Can we see some mutation?

# %%
my_mut_offspring, my_mut_offspring_fitness = mutation(my_offspring)
my_offspring
my_mut_offspring
# Out:
# array([[ 3.47909899,  3.757548  , -3.05425909,  0.4062219 ,  0.15597427,
#          2.30206468],
#        [ 1.54467246,  2.49041854, -3.60489863,  0.61102454,  2.12192114,
#         -3.10469033],
#        [-3.08516982,  1.6246642 , -3.92401418, -2.90685786, -3.82616072,
#         -2.0560268 ]])
# array([[ 3.47909899,  3.757548  , -3.05425909,  0.4062219 ,  0.15597427,
#          2.30206468],
#        [ 1.121633  ,  2.62324295, -3.64402157,  0.86303807,  1.80523192,
#         -3.38117668],
#        [-3.08516982,  1.6246642 , -3.92401418, -2.90685786, -3.82616072,
#         -2.0560268 ]])

# %% [markdown]
# # Environmental selection
# The final step is environmental selection. This comes in two parts:
#
# 1) Imposing any hard constraints, such as those violating range being chucked out
#
# 2) Picking the `POP_SIZE` best individuals and sending them to the next generation
#
#
#
# Let's first throw out any individuals not adhering to the limits set by or constraints

# %%
#RULING OUT BROS THAT ARE OUT OF THE CONSTRAINT RANGE

def hard_constraint(t_total_pop):
    """ Scans the array for individual violating constraint bounds
    and chucks them out of processing

    t_all includes all vectors (parents + mutated offsprings)
    """
    idx1 = (t_total_pop >= -4.0)
    idx2 = (t_total_pop <= 4.0)

    # And condition as both must be satisfied
    idx = idx1 & idx2

    # Returns an entire row as false even if one evaluares to False
    # The axis argument tells along which axis it should scan
    idx = np.all(idx, axis=1)

    return t_total_pop[idx]
    # return np.clip(modified_pop, a_min=-4.0, a_max=4.0)

# %% [markdown]
# Let's see if the constraint check passes. Let's concatenate all vectors into one big unit and do constraint check.

# %%
#STACKING OFFSPRING ON TOP OF THE ORIGINAL POPULATION
# Testing constraints 
# Group curr_population, my_parents, my_mut_offspring here
# Stack them one top of another
total_population = np.vstack((curr_population, my_mut_offspring))

# Verify shape
total_population.shape

total_population = hard_constraint(total_population)
# Out:
# (13, 6)

# %% [markdown]
# We then pick the top `POP_SIZE` individuals next, based on their fitness

# %%
#PICK THE BEST 10 OUT OF ALL OF EM
def environmental_selection(t_total_pop):
    """ Calculate total population (after constraint checking) fitness,
    rank accoridingly and select only the top POP_SIZE individuals to
    pass on to the next generation
    """ 

    tot_fitness = calc_fitness(t_total_pop)
    
    # Calculate elements from small->top fitness
    idx = np.argsort(tot_fitness)
    
    # Reverse to give top->small fitness
    idx = idx[::-1]
    
    # Cut off POP_SIZE elements
    idx = idx[:POP_SIZE]

    # Return corresponding population
    return t_total_pop[idx]

# %% [markdown]
# Check whether selecting top 10 works...

# %%
print("Before")
total_population.shape
calc_fitness(total_population)
new_population = environmental_selection(total_population)
print("After")
new_population.shape
calc_fitness(new_population)
# Out:
# Before
# (13, 6)
# array([-32.78451566,  38.78266823,  56.54288246,  43.29910463,
#         19.91668086, -28.88903058,   5.03723498, -13.61482319,
#         -4.86470855,  38.6479782 ,  61.73886227,  71.1093877 ,
#          6.0554313 ])
# After
# (10, 6)
# array([71.1093877 , 61.73886227, 56.54288246, 43.29910463, 38.78266823,
#        38.6479782 , 19.91668086,  6.0554313 ,  5.03723498, -4.86470855])

# %% [markdown]
# # Let's hook them all up together!

# %% [markdown]
# And add some utilities to help us track progress

# %%
best_outputs = []
num_generations = 1000
curr_population = np.random.uniform(low=-4.0, high=4.0, size=DOFS_IN_POP)
print(curr_population)
overall_max_fitness = -99999

# Run many iterations
# You should also have another convergence check
for generation in range(num_generations):
    print("Generation : ", generation)

    # Measuring the fitness of each chromosome in the population.
    fitness = calc_fitness(curr_population)

    # print("Fitness")
    # print(fitness)

    max_fitness = np.max(fitness)

    # The best result in the current iteration.
    print("Best result in current iteration {0} compared to overall {1}".format(max_fitness, max(max_fitness, overall_max_fitness)))
    best_outputs.append(max_fitness)
    
    # Selecting the best parents in the population for mating.
    parents, _ = select_determinstic(curr_population, fitness)
#     parents, _ = select_stochastic(curr_population, fitness)
    
    # print("Parents")
    # print(parents)

    # Generating next generation using crossover.
    offspring_crossed, _ = crossover(parents)

    # print("Crossover")
    # print(offspring_crossover)

    # Adding some variations to the offspring using mutation.
    offspring_mutated, _ = mutation(offspring_crossed)

    # print("Mutation")
    # print(offspring_mutation)

    # Check for constraints
    total_population = np.vstack((curr_population, offspring_mutated))
    total_population = hard_constraint(total_population)

    # Environmental selection
    curr_population = environmental_selection(total_population)
              
# Getting the best solution after iterating finishing all generations.
#At first, the fitness is calculated for each solution in the final generation.
fitness = calc_fitness(curr_population)

# Then return the index of that solution corresponding to the best fitness.
max_idx = np.argmax(fitness)

print("Best solution : ", curr_population[max_idx, :])
print("Best solution fitness : ", fitness[max_idx])
# Out:
# [[ 3.96927201  0.10190183 -1.80253701  2.2308894  -3.13663631  1.05084125]
#  [-3.88379651 -3.64439427 -0.45840999  2.66686868  3.00900867  2.54415327]
#  [-0.42474479 -1.12216421 -3.95558646  1.55819443  3.94190886 -0.07858038]
#  [ 3.99091915  1.28264347 -1.69982362 -1.89261082  3.40470741 -2.77488363]
#  [-2.46404878 -3.03333851 -3.79869924  3.54664746 -0.93740141 -1.53517948]
#  [ 0.13161074 -2.43543599 -2.99527096 -3.17223728  2.71019146 -1.72752411]
#  [-0.42256669 -3.32413031 -2.99323342  1.53504376 -1.10542292 -3.51896282]
#  [ 3.23593027  0.41238825  1.83795165 -3.79962699  1.98115911 -2.52725089]
#  [-3.10169098 -1.34495971 -3.01921758  2.05043587 -1.8979144  -0.25006828]
#  [ 2.05869562 -3.79095544  3.77360413 -1.01044859  0.67078185 -3.89200723]]
# Generation :  0
# Best result in current iteration 60.04142864076309 compared to overall 60.04142864076309
# Generation :  1
# Best result in current iteration 61.22023577132712 compared to overall 61.22023577132712
# Generation :  2
# Best result in current iteration 61.30858676871329 compared to overall 61.30858676871329
# Generation :  3
# Best result in current iteration 62.51303898702542 compared to overall 62.51303898702542
# Generation :  4
# Best result in current iteration 62.51303898702542 compared to overall 62.51303898702542
# Generation :  5
# Best result in current iteration 62.51303898702542 compared to overall 62.51303898702542
# Generation :  6
# Best result in current iteration 64.01819539017991 compared to overall 64.01819539017991
# Generation :  7
# Best result in current iteration 64.79666264518032 compared to overall 64.79666264518032
# Generation :  8
# Best result in current iteration 64.79666264518032 compared to overall 64.79666264518032
# Generation :  9
# Best result in current iteration 64.79666264518032 compared to overall 64.79666264518032
# Generation :  10
# Best result in current iteration 65.11127297336456 compared to overall 65.11127297336456
# Generation :  11
# Best result in current iteration 65.3559265994018 compared to overall 65.3559265994018
# Generation :  12
# Best result in current iteration 70.21134097608928 compared to overall 70.21134097608928
# Generation :  13
# Best result in current iteration 70.21134097608928 compared to overall 70.21134097608928
# Generation :  14
# Best result in current iteration 70.21134097608928 compared to overall 70.21134097608928
# Generation :  15
# Best result in current iteration 70.21134097608928 compared to overall 70.21134097608928
# Generation :  16
# Best result in current iteration 70.21134097608928 compared to overall 70.21134097608928
# Generation :  17
# Best result in current iteration 70.21134097608928 compared to overall 70.21134097608928
# Generation :  18
# Best result in current iteration 70.21134097608928 compared to overall 70.21134097608928
# Generation :  19
# Best result in current iteration 70.21134097608928 compared to overall 70.21134097608928
# Generation :  20
# Best result in current iteration 70.90595053224519 compared to overall 70.90595053224519
# Generation :  21
# Best result in current iteration 70.90595053224519 compared to overall 70.90595053224519
# Generation :  22
# Best result in current iteration 74.39794462645389 compared to overall 74.39794462645389
# Generation :  23
# Best result in current iteration 75.21977455668194 compared to overall 75.21977455668194
# Generation :  24
# Best result in current iteration 75.21977455668194 compared to overall 75.21977455668194
# Generation :  25
# Best result in current iteration 78.486686155442 compared to overall 78.486686155442
# Generation :  26
# Best result in current iteration 78.486686155442 compared to overall 78.486686155442
# Generation :  27
# Best result in current iteration 78.56122630848904 compared to overall 78.56122630848904
# Generation :  28
# Best result in current iteration 79.64936417712404 compared to overall 79.64936417712404
# Generation :  29
# Best result in current iteration 80.4821685868447 compared to overall 80.4821685868447
# Generation :  30
# Best result in current iteration 80.4821685868447 compared to overall 80.4821685868447
# Generation :  31
# Best result in current iteration 80.4821685868447 compared to overall 80.4821685868447
# Generation :  32
# Best result in current iteration 85.38849981960843 compared to overall 85.38849981960843
# Generation :  33
# Best result in current iteration 86.353246007599 compared to overall 86.353246007599
# Generation :  34
# Best result in current iteration 86.353246007599 compared to overall 86.353246007599
# Generation :  35
# Best result in current iteration 87.17267789244437 compared to overall 87.17267789244437
# Generation :  36
# Best result in current iteration 89.73406371619703 compared to overall 89.73406371619703
# Generation :  37
# Best result in current iteration 90.93081957063626 compared to overall 90.93081957063626
# Generation :  38
# Best result in current iteration 90.93081957063626 compared to overall 90.93081957063626
# Generation :  39
# Best result in current iteration 91.28516193006067 compared to overall 91.28516193006067
# Generation :  40
# Best result in current iteration 91.28516193006067 compared to overall 91.28516193006067
# Generation :  41
# Best result in current iteration 91.28516193006067 compared to overall 91.28516193006067
# Generation :  42
# Best result in current iteration 91.28516193006067 compared to overall 91.28516193006067
# Generation :  43
# Best result in current iteration 92.30657186448781 compared to overall 92.30657186448781
# Generation :  44
# Best result in current iteration 94.82898892049751 compared to overall 94.82898892049751
# Generation :  45
# Best result in current iteration 94.82898892049751 compared to overall 94.82898892049751
# Generation :  46
# Best result in current iteration 97.11734567736862 compared to overall 97.11734567736862
# Generation :  47
# Best result in current iteration 97.11734567736862 compared to overall 97.11734567736862
# Generation :  48
# Best result in current iteration 97.11734567736862 compared to overall 97.11734567736862
# Generation :  49
# Best result in current iteration 97.11734567736862 compared to overall 97.11734567736862
# Generation :  50
# Best result in current iteration 97.11734567736862 compared to overall 97.11734567736862
# Generation :  51
# Best result in current iteration 97.11734567736862 compared to overall 97.11734567736862
# Generation :  52
# Best result in current iteration 102.05911254934666 compared to overall 102.05911254934666
# Generation :  53
# Best result in current iteration 102.05911254934666 compared to overall 102.05911254934666
# Generation :  54
# Best result in current iteration 102.05911254934666 compared to overall 102.05911254934666
# Generation :  55
# Best result in current iteration 102.05911254934666 compared to overall 102.05911254934666
# Generation :  56
# Best result in current iteration 102.05911254934666 compared to overall 102.05911254934666
# Generation :  57
# Best result in current iteration 102.05911254934666 compared to overall 102.05911254934666
# Generation :  58
# Best result in current iteration 102.05911254934666 compared to overall 102.05911254934666
# Generation :  59
# Best result in current iteration 102.05911254934666 compared to overall 102.05911254934666
# Generation :  60
# Best result in current iteration 102.05911254934666 compared to overall 102.05911254934666
# Generation :  61
# Best result in current iteration 102.05911254934666 compared to overall 102.05911254934666
# Generation :  62
# Best result in current iteration 102.05911254934666 compared to overall 102.05911254934666
# Generation :  63
# Best result in current iteration 102.05911254934666 compared to overall 102.05911254934666
# Generation :  64
# Best result in current iteration 102.05911254934666 compared to overall 102.05911254934666
# Generation :  65
# Best result in current iteration 102.05911254934666 compared to overall 102.05911254934666
# Generation :  66
# Best result in current iteration 102.05911254934666 compared to overall 102.05911254934666
# Generation :  67
# Best result in current iteration 102.05911254934666 compared to overall 102.05911254934666
# Generation :  68
# Best result in current iteration 102.05911254934666 compared to overall 102.05911254934666
# Generation :  69
# Best result in current iteration 102.05911254934666 compared to overall 102.05911254934666
# Generation :  70
# Best result in current iteration 102.05911254934666 compared to overall 102.05911254934666
# Generation :  71
# Best result in current iteration 102.05911254934666 compared to overall 102.05911254934666
# Generation :  72
# Best result in current iteration 102.05911254934666 compared to overall 102.05911254934666
# Generation :  73
# Best result in current iteration 102.05911254934666 compared to overall 102.05911254934666
# Generation :  74
# Best result in current iteration 102.05911254934666 compared to overall 102.05911254934666
# Generation :  75
# Best result in current iteration 102.05911254934666 compared to overall 102.05911254934666
# Generation :  76
# Best result in current iteration 102.05911254934666 compared to overall 102.05911254934666
# Generation :  77
# Best result in current iteration 102.05911254934666 compared to overall 102.05911254934666
# Generation :  78
# Best result in current iteration 102.05911254934666 compared to overall 102.05911254934666
# Generation :  79
# Best result in current iteration 102.05911254934666 compared to overall 102.05911254934666
# Generation :  80
# Best result in current iteration 102.05911254934666 compared to overall 102.05911254934666
# Generation :  81
# Best result in current iteration 102.05911254934666 compared to overall 102.05911254934666
# Generation :  82
# Best result in current iteration 102.05911254934666 compared to overall 102.05911254934666
# Generation :  83
# Best result in current iteration 102.05911254934666 compared to overall 102.05911254934666
# Generation :  84
# Best result in current iteration 102.05911254934666 compared to overall 102.05911254934666
# Generation :  85
# Best result in current iteration 102.05911254934666 compared to overall 102.05911254934666
# Generation :  86
# Best result in current iteration 102.05911254934666 compared to overall 102.05911254934666
# Generation :  87
# Best result in current iteration 102.05911254934666 compared to overall 102.05911254934666
# Generation :  88
# Best result in current iteration 102.05911254934666 compared to overall 102.05911254934666
# Generation :  89
# Best result in current iteration 102.05911254934666 compared to overall 102.05911254934666
# Generation :  90
# Best result in current iteration 102.05911254934666 compared to overall 102.05911254934666
# Generation :  91
# Best result in current iteration 102.05911254934666 compared to overall 102.05911254934666
# Generation :  92
# Best result in current iteration 102.05911254934666 compared to overall 102.05911254934666
# Generation :  93
# Best result in current iteration 102.05911254934666 compared to overall 102.05911254934666
# Generation :  94
# Best result in current iteration 102.05911254934666 compared to overall 102.05911254934666
# Generation :  95
# Best result in current iteration 102.05911254934666 compared to overall 102.05911254934666
# Generation :  96
# Best result in current iteration 102.05911254934666 compared to overall 102.05911254934666
# Generation :  97
# Best result in current iteration 102.05911254934666 compared to overall 102.05911254934666
# Generation :  98
# Best result in current iteration 102.05911254934666 compared to overall 102.05911254934666
# Generation :  99
# Best result in current iteration 102.05911254934666 compared to overall 102.05911254934666
# Generation :  100
# Best result in current iteration 102.05911254934666 compared to overall 102.05911254934666
# Generation :  101
# Best result in current iteration 102.05911254934666 compared to overall 102.05911254934666
# Generation :  102
# Best result in current iteration 102.05911254934666 compared to overall 102.05911254934666
# Generation :  103
# Best result in current iteration 102.05911254934666 compared to overall 102.05911254934666
# Generation :  104
# Best result in current iteration 102.05911254934666 compared to overall 102.05911254934666
# Generation :  105
# Best result in current iteration 102.05911254934666 compared to overall 102.05911254934666
# Generation :  106
# Best result in current iteration 102.05911254934666 compared to overall 102.05911254934666
# Generation :  107
# Best result in current iteration 102.05911254934666 compared to overall 102.05911254934666
# Generation :  108
# Best result in current iteration 102.05911254934666 compared to overall 102.05911254934666
# Generation :  109
# Best result in current iteration 102.05911254934666 compared to overall 102.05911254934666
# Generation :  110
# Best result in current iteration 102.05911254934666 compared to overall 102.05911254934666
# Generation :  111
# Best result in current iteration 102.05911254934666 compared to overall 102.05911254934666
# Generation :  112
# Best result in current iteration 102.05911254934666 compared to overall 102.05911254934666
# Generation :  113
# Best result in current iteration 102.05911254934666 compared to overall 102.05911254934666
# Generation :  114
# Best result in current iteration 102.05911254934666 compared to overall 102.05911254934666
# Generation :  115
# Best result in current iteration 102.05911254934666 compared to overall 102.05911254934666
# Generation :  116
# Best result in current iteration 102.05911254934666 compared to overall 102.05911254934666
# Generation :  117
# Best result in current iteration 102.05911254934666 compared to overall 102.05911254934666
# Generation :  118
# Best result in current iteration 102.05911254934666 compared to overall 102.05911254934666
# Generation :  119
# Best result in current iteration 102.05911254934666 compared to overall 102.05911254934666
# Generation :  120
# Best result in current iteration 102.05911254934666 compared to overall 102.05911254934666
# Generation :  121
# Best result in current iteration 102.05911254934666 compared to overall 102.05911254934666
# Generation :  122
# Best result in current iteration 102.05911254934666 compared to overall 102.05911254934666
# Generation :  123
# Best result in current iteration 102.05911254934666 compared to overall 102.05911254934666
# Generation :  124
# Best result in current iteration 102.05911254934666 compared to overall 102.05911254934666
# Generation :  125
# Best result in current iteration 102.05911254934666 compared to overall 102.05911254934666
# Generation :  126
# Best result in current iteration 102.05911254934666 compared to overall 102.05911254934666
# Generation :  127
# Best result in current iteration 102.05911254934666 compared to overall 102.05911254934666
# Generation :  128
# Best result in current iteration 102.05911254934666 compared to overall 102.05911254934666
# Generation :  129
# Best result in current iteration 102.05911254934666 compared to overall 102.05911254934666
# Generation :  130
# Best result in current iteration 102.05911254934666 compared to overall 102.05911254934666
# Generation :  131
# Best result in current iteration 102.05911254934666 compared to overall 102.05911254934666
# Generation :  132
# Best result in current iteration 102.05911254934666 compared to overall 102.05911254934666
# Generation :  133
# Best result in current iteration 102.05911254934666 compared to overall 102.05911254934666
# Generation :  134
# Best result in current iteration 102.05911254934666 compared to overall 102.05911254934666
# Generation :  135
# Best result in current iteration 102.05911254934666 compared to overall 102.05911254934666
# Generation :  136
# Best result in current iteration 102.05911254934666 compared to overall 102.05911254934666
# Generation :  137
# Best result in current iteration 102.05911254934666 compared to overall 102.05911254934666
# Generation :  138
# Best result in current iteration 102.05911254934666 compared to overall 102.05911254934666
# Generation :  139
# Best result in current iteration 102.05911254934666 compared to overall 102.05911254934666
# Generation :  140
# Best result in current iteration 102.05911254934666 compared to overall 102.05911254934666
# Generation :  141
# Best result in current iteration 102.05911254934666 compared to overall 102.05911254934666
# Generation :  142
# Best result in current iteration 102.05911254934666 compared to overall 102.05911254934666
# Generation :  143
# Best result in current iteration 102.05911254934666 compared to overall 102.05911254934666
# Generation :  144
# Best result in current iteration 102.05911254934666 compared to overall 102.05911254934666
# Generation :  145
# Best result in current iteration 102.05911254934666 compared to overall 102.05911254934666
# Generation :  146
# Best result in current iteration 102.05911254934666 compared to overall 102.05911254934666
# Generation :  147
# Best result in current iteration 102.05911254934666 compared to overall 102.05911254934666
# Generation :  148
# Best result in current iteration 102.05911254934666 compared to overall 102.05911254934666
# Generation :  149
# Best result in current iteration 102.05911254934666 compared to overall 102.05911254934666
# Generation :  150
# Best result in current iteration 102.05911254934666 compared to overall 102.05911254934666
# Generation :  151
# Best result in current iteration 102.05911254934666 compared to overall 102.05911254934666
# Generation :  152
# Best result in current iteration 102.05911254934666 compared to overall 102.05911254934666
# Generation :  153
# Best result in current iteration 102.05911254934666 compared to overall 102.05911254934666
# Generation :  154
# Best result in current iteration 102.05911254934666 compared to overall 102.05911254934666
# Generation :  155
# Best result in current iteration 102.05911254934666 compared to overall 102.05911254934666
# Generation :  156
# Best result in current iteration 102.05911254934666 compared to overall 102.05911254934666
# Generation :  157
# Best result in current iteration 102.05911254934666 compared to overall 102.05911254934666
# Generation :  158
# Best result in current iteration 102.05911254934666 compared to overall 102.05911254934666
# Generation :  159
# Best result in current iteration 102.05911254934666 compared to overall 102.05911254934666
# Generation :  160
# Best result in current iteration 102.05911254934666 compared to overall 102.05911254934666
# Generation :  161
# Best result in current iteration 102.05911254934666 compared to overall 102.05911254934666
# Generation :  162
# Best result in current iteration 102.05911254934666 compared to overall 102.05911254934666
# Generation :  163
# Best result in current iteration 102.05911254934666 compared to overall 102.05911254934666
# Generation :  164
# Best result in current iteration 102.05911254934666 compared to overall 102.05911254934666
# Generation :  165
# Best result in current iteration 102.31258487840614 compared to overall 102.31258487840614
# Generation :  166
# Best result in current iteration 102.77316295867226 compared to overall 102.77316295867226
# Generation :  167
# Best result in current iteration 102.77316295867226 compared to overall 102.77316295867226
# Generation :  168
# Best result in current iteration 102.77316295867226 compared to overall 102.77316295867226
# Generation :  169
# Best result in current iteration 104.12659947616078 compared to overall 104.12659947616078
# Generation :  170
# Best result in current iteration 104.12659947616078 compared to overall 104.12659947616078
# Generation :  171
# Best result in current iteration 104.12659947616078 compared to overall 104.12659947616078
# Generation :  172
# Best result in current iteration 104.12659947616078 compared to overall 104.12659947616078
# Generation :  173
# Best result in current iteration 104.12659947616078 compared to overall 104.12659947616078
# Generation :  174
# Best result in current iteration 104.12659947616078 compared to overall 104.12659947616078
# Generation :  175
# Best result in current iteration 104.12659947616078 compared to overall 104.12659947616078
# Generation :  176
# Best result in current iteration 104.12659947616078 compared to overall 104.12659947616078
# Generation :  177
# Best result in current iteration 104.12659947616078 compared to overall 104.12659947616078
# Generation :  178
# Best result in current iteration 104.12659947616078 compared to overall 104.12659947616078
# Generation :  179
# Best result in current iteration 104.12659947616078 compared to overall 104.12659947616078
# Generation :  180
# Best result in current iteration 104.12659947616078 compared to overall 104.12659947616078
# Generation :  181
# Best result in current iteration 104.12659947616078 compared to overall 104.12659947616078
# Generation :  182
# Best result in current iteration 104.12659947616078 compared to overall 104.12659947616078
# Generation :  183
# Best result in current iteration 104.12659947616078 compared to overall 104.12659947616078
# Generation :  184
# Best result in current iteration 104.12659947616078 compared to overall 104.12659947616078
# Generation :  185
# Best result in current iteration 104.12659947616078 compared to overall 104.12659947616078
# Generation :  186
# Best result in current iteration 104.12659947616078 compared to overall 104.12659947616078
# Generation :  187
# Best result in current iteration 104.12659947616078 compared to overall 104.12659947616078
# Generation :  188
# Best result in current iteration 104.12659947616078 compared to overall 104.12659947616078
# Generation :  189
# Best result in current iteration 104.12659947616078 compared to overall 104.12659947616078
# Generation :  190
# Best result in current iteration 104.12659947616078 compared to overall 104.12659947616078
# Generation :  191
# Best result in current iteration 104.12659947616078 compared to overall 104.12659947616078
# Generation :  192
# Best result in current iteration 104.12659947616078 compared to overall 104.12659947616078
# Generation :  193
# Best result in current iteration 104.12659947616078 compared to overall 104.12659947616078
# Generation :  194
# Best result in current iteration 104.12659947616078 compared to overall 104.12659947616078
# Generation :  195
# Best result in current iteration 104.12659947616078 compared to overall 104.12659947616078
# Generation :  196
# Best result in current iteration 104.12659947616078 compared to overall 104.12659947616078
# Generation :  197
# Best result in current iteration 104.12659947616078 compared to overall 104.12659947616078
# Generation :  198
# Best result in current iteration 104.12659947616078 compared to overall 104.12659947616078
# Generation :  199
# Best result in current iteration 104.12659947616078 compared to overall 104.12659947616078
# Generation :  200
# Best result in current iteration 104.12659947616078 compared to overall 104.12659947616078
# Generation :  201
# Best result in current iteration 104.12659947616078 compared to overall 104.12659947616078
# Generation :  202
# Best result in current iteration 104.12659947616078 compared to overall 104.12659947616078
# Generation :  203
# Best result in current iteration 105.11301261374105 compared to overall 105.11301261374105
# Generation :  204
# Best result in current iteration 105.11301261374105 compared to overall 105.11301261374105
# Generation :  205
# Best result in current iteration 105.11301261374105 compared to overall 105.11301261374105
# Generation :  206
# Best result in current iteration 105.11301261374105 compared to overall 105.11301261374105
# Generation :  207
# Best result in current iteration 105.11301261374105 compared to overall 105.11301261374105
# Generation :  208
# Best result in current iteration 105.11301261374105 compared to overall 105.11301261374105
# Generation :  209
# Best result in current iteration 105.11301261374105 compared to overall 105.11301261374105
# Generation :  210
# Best result in current iteration 105.11301261374105 compared to overall 105.11301261374105
# Generation :  211
# Best result in current iteration 105.11301261374105 compared to overall 105.11301261374105
# Generation :  212
# Best result in current iteration 107.83118142962505 compared to overall 107.83118142962505
# Generation :  213
# Best result in current iteration 107.83118142962505 compared to overall 107.83118142962505
# Generation :  214
# Best result in current iteration 107.83118142962505 compared to overall 107.83118142962505
# Generation :  215
# Best result in current iteration 107.83118142962505 compared to overall 107.83118142962505
# Generation :  216
# Best result in current iteration 107.83118142962505 compared to overall 107.83118142962505
# Generation :  217
# Best result in current iteration 107.83118142962505 compared to overall 107.83118142962505
# Generation :  218
# Best result in current iteration 107.83118142962505 compared to overall 107.83118142962505
# Generation :  219
# Best result in current iteration 107.83118142962505 compared to overall 107.83118142962505
# Generation :  220
# Best result in current iteration 107.83118142962505 compared to overall 107.83118142962505
# Generation :  221
# Best result in current iteration 107.83118142962505 compared to overall 107.83118142962505
# Generation :  222
# Best result in current iteration 107.83118142962505 compared to overall 107.83118142962505
# Generation :  223
# Best result in current iteration 107.83118142962505 compared to overall 107.83118142962505
# Generation :  224
# Best result in current iteration 107.83118142962505 compared to overall 107.83118142962505
# Generation :  225
# Best result in current iteration 107.83118142962505 compared to overall 107.83118142962505
# Generation :  226
# Best result in current iteration 107.83118142962505 compared to overall 107.83118142962505
# Generation :  227
# Best result in current iteration 107.83118142962505 compared to overall 107.83118142962505
# Generation :  228
# Best result in current iteration 107.83118142962505 compared to overall 107.83118142962505
# Generation :  229
# Best result in current iteration 107.83118142962505 compared to overall 107.83118142962505
# Generation :  230
# Best result in current iteration 107.83118142962505 compared to overall 107.83118142962505
# Generation :  231
# Best result in current iteration 107.83118142962505 compared to overall 107.83118142962505
# Generation :  232
# Best result in current iteration 107.83118142962505 compared to overall 107.83118142962505
# Generation :  233
# Best result in current iteration 107.83118142962505 compared to overall 107.83118142962505
# Generation :  234
# Best result in current iteration 107.83118142962505 compared to overall 107.83118142962505
# Generation :  235
# Best result in current iteration 107.83118142962505 compared to overall 107.83118142962505
# Generation :  236
# Best result in current iteration 107.83118142962505 compared to overall 107.83118142962505
# Generation :  237
# Best result in current iteration 107.83118142962505 compared to overall 107.83118142962505
# Generation :  238
# Best result in current iteration 107.83118142962505 compared to overall 107.83118142962505
# Generation :  239
# Best result in current iteration 107.83118142962505 compared to overall 107.83118142962505
# Generation :  240
# Best result in current iteration 107.83118142962505 compared to overall 107.83118142962505
# Generation :  241
# Best result in current iteration 107.83118142962505 compared to overall 107.83118142962505
# Generation :  242
# Best result in current iteration 107.83118142962505 compared to overall 107.83118142962505
# Generation :  243
# Best result in current iteration 107.83118142962505 compared to overall 107.83118142962505
# Generation :  244
# Best result in current iteration 107.83118142962505 compared to overall 107.83118142962505
# Generation :  245
# Best result in current iteration 107.83118142962505 compared to overall 107.83118142962505
# Generation :  246
# Best result in current iteration 107.83118142962505 compared to overall 107.83118142962505
# Generation :  247
# Best result in current iteration 107.83118142962505 compared to overall 107.83118142962505
# Generation :  248
# Best result in current iteration 107.83118142962505 compared to overall 107.83118142962505
# Generation :  249
# Best result in current iteration 107.83118142962505 compared to overall 107.83118142962505
# Generation :  250
# Best result in current iteration 107.83118142962505 compared to overall 107.83118142962505
# Generation :  251
# Best result in current iteration 107.83118142962505 compared to overall 107.83118142962505
# Generation :  252
# Best result in current iteration 107.83118142962505 compared to overall 107.83118142962505
# Generation :  253
# Best result in current iteration 107.83118142962505 compared to overall 107.83118142962505
# Generation :  254
# Best result in current iteration 107.83118142962505 compared to overall 107.83118142962505
# Generation :  255
# Best result in current iteration 107.83118142962505 compared to overall 107.83118142962505
# Generation :  256
# Best result in current iteration 107.83118142962505 compared to overall 107.83118142962505
# Generation :  257
# Best result in current iteration 107.83118142962505 compared to overall 107.83118142962505
# Generation :  258
# Best result in current iteration 107.83118142962505 compared to overall 107.83118142962505
# Generation :  259
# Best result in current iteration 107.83118142962505 compared to overall 107.83118142962505
# Generation :  260
# Best result in current iteration 107.83118142962505 compared to overall 107.83118142962505
# Generation :  261
# Best result in current iteration 107.83118142962505 compared to overall 107.83118142962505
# Generation :  262
# Best result in current iteration 107.83118142962505 compared to overall 107.83118142962505
# Generation :  263
# Best result in current iteration 107.83118142962505 compared to overall 107.83118142962505
# Generation :  264
# Best result in current iteration 107.83118142962505 compared to overall 107.83118142962505
# Generation :  265
# Best result in current iteration 107.83118142962505 compared to overall 107.83118142962505
# Generation :  266
# Best result in current iteration 107.83118142962505 compared to overall 107.83118142962505
# Generation :  267
# Best result in current iteration 107.83118142962505 compared to overall 107.83118142962505
# Generation :  268
# Best result in current iteration 107.83118142962505 compared to overall 107.83118142962505
# Generation :  269
# Best result in current iteration 107.83118142962505 compared to overall 107.83118142962505
# Generation :  270
# Best result in current iteration 107.83118142962505 compared to overall 107.83118142962505
# Generation :  271
# Best result in current iteration 107.83118142962505 compared to overall 107.83118142962505
# Generation :  272
# Best result in current iteration 107.83118142962505 compared to overall 107.83118142962505
# Generation :  273
# Best result in current iteration 107.83118142962505 compared to overall 107.83118142962505
# Generation :  274
# Best result in current iteration 107.83118142962505 compared to overall 107.83118142962505
# Generation :  275
# Best result in current iteration 107.83118142962505 compared to overall 107.83118142962505
# Generation :  276
# Best result in current iteration 107.83118142962505 compared to overall 107.83118142962505
# Generation :  277
# Best result in current iteration 107.83118142962505 compared to overall 107.83118142962505
# Generation :  278
# Best result in current iteration 107.83118142962505 compared to overall 107.83118142962505
# Generation :  279
# Best result in current iteration 107.83118142962505 compared to overall 107.83118142962505
# Generation :  280
# Best result in current iteration 107.83118142962505 compared to overall 107.83118142962505
# Generation :  281
# Best result in current iteration 107.83118142962505 compared to overall 107.83118142962505
# Generation :  282
# Best result in current iteration 107.83118142962505 compared to overall 107.83118142962505
# Generation :  283
# Best result in current iteration 107.83118142962505 compared to overall 107.83118142962505
# Generation :  284
# Best result in current iteration 107.83118142962505 compared to overall 107.83118142962505
# Generation :  285
# Best result in current iteration 107.83118142962505 compared to overall 107.83118142962505
# Generation :  286
# Best result in current iteration 107.83118142962505 compared to overall 107.83118142962505
# Generation :  287
# Best result in current iteration 107.83118142962505 compared to overall 107.83118142962505
# Generation :  288
# Best result in current iteration 107.83118142962505 compared to overall 107.83118142962505
# Generation :  289
# Best result in current iteration 107.83118142962505 compared to overall 107.83118142962505
# Generation :  290
# Best result in current iteration 107.83118142962505 compared to overall 107.83118142962505
# Generation :  291
# Best result in current iteration 107.83118142962505 compared to overall 107.83118142962505
# Generation :  292
# Best result in current iteration 107.83118142962505 compared to overall 107.83118142962505
# Generation :  293
# Best result in current iteration 107.83118142962505 compared to overall 107.83118142962505
# Generation :  294
# Best result in current iteration 107.83118142962505 compared to overall 107.83118142962505
# Generation :  295
# Best result in current iteration 107.83118142962505 compared to overall 107.83118142962505
# Generation :  296
# Best result in current iteration 107.83118142962505 compared to overall 107.83118142962505
# Generation :  297
# Best result in current iteration 107.83118142962505 compared to overall 107.83118142962505
# Generation :  298
# Best result in current iteration 107.83118142962505 compared to overall 107.83118142962505
# Generation :  299
# Best result in current iteration 107.83118142962505 compared to overall 107.83118142962505
# Generation :  300
# Best result in current iteration 107.83118142962505 compared to overall 107.83118142962505
# Generation :  301
# Best result in current iteration 107.83118142962505 compared to overall 107.83118142962505
# Generation :  302
# Best result in current iteration 107.83118142962505 compared to overall 107.83118142962505
# Generation :  303
# Best result in current iteration 107.83118142962505 compared to overall 107.83118142962505
# Generation :  304
# Best result in current iteration 107.83118142962505 compared to overall 107.83118142962505
# Generation :  305
# Best result in current iteration 107.83118142962505 compared to overall 107.83118142962505
# Generation :  306
# Best result in current iteration 107.83118142962505 compared to overall 107.83118142962505
# Generation :  307
# Best result in current iteration 107.83118142962505 compared to overall 107.83118142962505
# Generation :  308
# Best result in current iteration 107.83118142962505 compared to overall 107.83118142962505
# Generation :  309
# Best result in current iteration 107.83118142962505 compared to overall 107.83118142962505
# Generation :  310
# Best result in current iteration 107.83118142962505 compared to overall 107.83118142962505
# Generation :  311
# Best result in current iteration 107.83118142962505 compared to overall 107.83118142962505
# Generation :  312
# Best result in current iteration 107.83118142962505 compared to overall 107.83118142962505
# Generation :  313
# Best result in current iteration 109.0897368984105 compared to overall 109.0897368984105
# Generation :  314
# Best result in current iteration 109.0897368984105 compared to overall 109.0897368984105
# Generation :  315
# Best result in current iteration 109.0897368984105 compared to overall 109.0897368984105
# Generation :  316
# Best result in current iteration 109.0897368984105 compared to overall 109.0897368984105
# Generation :  317
# Best result in current iteration 109.0897368984105 compared to overall 109.0897368984105
# Generation :  318
# Best result in current iteration 109.0897368984105 compared to overall 109.0897368984105
# Generation :  319
# Best result in current iteration 109.0897368984105 compared to overall 109.0897368984105
# Generation :  320
# Best result in current iteration 109.0897368984105 compared to overall 109.0897368984105
# Generation :  321
# Best result in current iteration 109.0897368984105 compared to overall 109.0897368984105
# Generation :  322
# Best result in current iteration 109.0897368984105 compared to overall 109.0897368984105
# Generation :  323
# Best result in current iteration 109.0897368984105 compared to overall 109.0897368984105
# Generation :  324
# Best result in current iteration 109.0897368984105 compared to overall 109.0897368984105
# Generation :  325
# Best result in current iteration 109.0897368984105 compared to overall 109.0897368984105
# Generation :  326
# Best result in current iteration 109.0897368984105 compared to overall 109.0897368984105
# Generation :  327
# Best result in current iteration 109.0897368984105 compared to overall 109.0897368984105
# Generation :  328
# Best result in current iteration 109.0897368984105 compared to overall 109.0897368984105
# Generation :  329
# Best result in current iteration 109.0897368984105 compared to overall 109.0897368984105
# Generation :  330
# Best result in current iteration 109.0897368984105 compared to overall 109.0897368984105
# Generation :  331
# Best result in current iteration 109.0897368984105 compared to overall 109.0897368984105
# Generation :  332
# Best result in current iteration 109.0897368984105 compared to overall 109.0897368984105
# Generation :  333
# Best result in current iteration 109.0897368984105 compared to overall 109.0897368984105
# Generation :  334
# Best result in current iteration 109.0897368984105 compared to overall 109.0897368984105
# Generation :  335
# Best result in current iteration 109.0897368984105 compared to overall 109.0897368984105
# Generation :  336
# Best result in current iteration 109.0897368984105 compared to overall 109.0897368984105
# Generation :  337
# Best result in current iteration 109.0897368984105 compared to overall 109.0897368984105
# Generation :  338
# Best result in current iteration 109.0897368984105 compared to overall 109.0897368984105
# Generation :  339
# Best result in current iteration 109.0897368984105 compared to overall 109.0897368984105
# Generation :  340
# Best result in current iteration 109.0897368984105 compared to overall 109.0897368984105
# Generation :  341
# Best result in current iteration 109.0897368984105 compared to overall 109.0897368984105
# Generation :  342
# Best result in current iteration 109.0897368984105 compared to overall 109.0897368984105
# Generation :  343
# Best result in current iteration 109.0897368984105 compared to overall 109.0897368984105
# Generation :  344
# Best result in current iteration 109.0897368984105 compared to overall 109.0897368984105
# Generation :  345
# Best result in current iteration 109.0897368984105 compared to overall 109.0897368984105
# Generation :  346
# Best result in current iteration 109.0897368984105 compared to overall 109.0897368984105
# Generation :  347
# Best result in current iteration 109.0897368984105 compared to overall 109.0897368984105
# Generation :  348
# Best result in current iteration 109.0897368984105 compared to overall 109.0897368984105
# Generation :  349
# Best result in current iteration 109.0897368984105 compared to overall 109.0897368984105
# Generation :  350
# Best result in current iteration 109.0897368984105 compared to overall 109.0897368984105
# Generation :  351
# Best result in current iteration 109.0897368984105 compared to overall 109.0897368984105
# Generation :  352
# Best result in current iteration 109.0897368984105 compared to overall 109.0897368984105
# Generation :  353
# Best result in current iteration 109.0897368984105 compared to overall 109.0897368984105
# Generation :  354
# Best result in current iteration 109.0897368984105 compared to overall 109.0897368984105
# Generation :  355
# Best result in current iteration 109.0897368984105 compared to overall 109.0897368984105
# Generation :  356
# Best result in current iteration 109.0897368984105 compared to overall 109.0897368984105
# Generation :  357
# Best result in current iteration 109.0897368984105 compared to overall 109.0897368984105
# Generation :  358
# Best result in current iteration 109.0897368984105 compared to overall 109.0897368984105
# Generation :  359
# Best result in current iteration 109.0897368984105 compared to overall 109.0897368984105
# Generation :  360
# Best result in current iteration 109.0897368984105 compared to overall 109.0897368984105
# Generation :  361
# Best result in current iteration 109.0897368984105 compared to overall 109.0897368984105
# Generation :  362
# Best result in current iteration 109.0897368984105 compared to overall 109.0897368984105
# Generation :  363
# Best result in current iteration 109.0897368984105 compared to overall 109.0897368984105
# Generation :  364
# Best result in current iteration 109.0897368984105 compared to overall 109.0897368984105
# Generation :  365
# Best result in current iteration 109.0897368984105 compared to overall 109.0897368984105
# Generation :  366
# Best result in current iteration 109.0897368984105 compared to overall 109.0897368984105
# Generation :  367
# Best result in current iteration 109.0897368984105 compared to overall 109.0897368984105
# Generation :  368
# Best result in current iteration 109.0897368984105 compared to overall 109.0897368984105
# Generation :  369
# Best result in current iteration 109.0897368984105 compared to overall 109.0897368984105
# Generation :  370
# Best result in current iteration 109.0897368984105 compared to overall 109.0897368984105
# Generation :  371
# Best result in current iteration 109.0897368984105 compared to overall 109.0897368984105
# Generation :  372
# Best result in current iteration 109.0897368984105 compared to overall 109.0897368984105
# Generation :  373
# Best result in current iteration 109.0897368984105 compared to overall 109.0897368984105
# Generation :  374
# Best result in current iteration 109.0897368984105 compared to overall 109.0897368984105
# Generation :  375
# Best result in current iteration 109.0897368984105 compared to overall 109.0897368984105
# Generation :  376
# Best result in current iteration 109.0897368984105 compared to overall 109.0897368984105
# Generation :  377
# Best result in current iteration 109.0897368984105 compared to overall 109.0897368984105
# Generation :  378
# Best result in current iteration 109.0897368984105 compared to overall 109.0897368984105
# Generation :  379
# Best result in current iteration 109.0897368984105 compared to overall 109.0897368984105
# Generation :  380
# Best result in current iteration 109.0897368984105 compared to overall 109.0897368984105
# Generation :  381
# Best result in current iteration 109.0897368984105 compared to overall 109.0897368984105
# Generation :  382
# Best result in current iteration 109.0897368984105 compared to overall 109.0897368984105
# Generation :  383
# Best result in current iteration 109.0897368984105 compared to overall 109.0897368984105
# Generation :  384
# Best result in current iteration 109.0897368984105 compared to overall 109.0897368984105
# Generation :  385
# Best result in current iteration 109.0897368984105 compared to overall 109.0897368984105
# Generation :  386
# Best result in current iteration 109.0897368984105 compared to overall 109.0897368984105
# Generation :  387
# Best result in current iteration 109.0897368984105 compared to overall 109.0897368984105
# Generation :  388
# Best result in current iteration 109.0897368984105 compared to overall 109.0897368984105
# Generation :  389
# Best result in current iteration 109.0897368984105 compared to overall 109.0897368984105
# Generation :  390
# Best result in current iteration 109.0897368984105 compared to overall 109.0897368984105
# Generation :  391
# Best result in current iteration 109.0897368984105 compared to overall 109.0897368984105
# Generation :  392
# Best result in current iteration 109.0897368984105 compared to overall 109.0897368984105
# Generation :  393
# Best result in current iteration 109.0897368984105 compared to overall 109.0897368984105
# Generation :  394
# Best result in current iteration 109.0897368984105 compared to overall 109.0897368984105
# Generation :  395
# Best result in current iteration 109.0897368984105 compared to overall 109.0897368984105
# Generation :  396
# Best result in current iteration 109.0897368984105 compared to overall 109.0897368984105
# Generation :  397
# Best result in current iteration 109.0897368984105 compared to overall 109.0897368984105
# Generation :  398
# Best result in current iteration 109.0897368984105 compared to overall 109.0897368984105
# Generation :  399
# Best result in current iteration 109.0897368984105 compared to overall 109.0897368984105
# Generation :  400
# Best result in current iteration 109.0897368984105 compared to overall 109.0897368984105
# Generation :  401
# Best result in current iteration 109.0897368984105 compared to overall 109.0897368984105
# Generation :  402
# Best result in current iteration 109.0897368984105 compared to overall 109.0897368984105
# Generation :  403
# Best result in current iteration 109.0897368984105 compared to overall 109.0897368984105
# Generation :  404
# Best result in current iteration 109.0897368984105 compared to overall 109.0897368984105
# Generation :  405
# Best result in current iteration 109.0897368984105 compared to overall 109.0897368984105
# Generation :  406
# Best result in current iteration 109.0897368984105 compared to overall 109.0897368984105
# Generation :  407
# Best result in current iteration 109.0897368984105 compared to overall 109.0897368984105
# Generation :  408
# Best result in current iteration 109.0897368984105 compared to overall 109.0897368984105
# Generation :  409
# Best result in current iteration 109.0897368984105 compared to overall 109.0897368984105
# Generation :  410
# Best result in current iteration 109.0897368984105 compared to overall 109.0897368984105
# Generation :  411
# Best result in current iteration 109.0897368984105 compared to overall 109.0897368984105
# Generation :  412
# Best result in current iteration 109.0897368984105 compared to overall 109.0897368984105
# Generation :  413
# Best result in current iteration 109.0897368984105 compared to overall 109.0897368984105
# Generation :  414
# Best result in current iteration 109.0897368984105 compared to overall 109.0897368984105
# Generation :  415
# Best result in current iteration 109.0897368984105 compared to overall 109.0897368984105
# Generation :  416
# Best result in current iteration 109.0897368984105 compared to overall 109.0897368984105
# Generation :  417
# Best result in current iteration 109.0897368984105 compared to overall 109.0897368984105
# Generation :  418
# Best result in current iteration 109.0897368984105 compared to overall 109.0897368984105
# Generation :  419
# Best result in current iteration 109.0897368984105 compared to overall 109.0897368984105
# Generation :  420
# Best result in current iteration 109.0897368984105 compared to overall 109.0897368984105
# Generation :  421
# Best result in current iteration 109.0897368984105 compared to overall 109.0897368984105
# Generation :  422
# Best result in current iteration 109.0897368984105 compared to overall 109.0897368984105
# Generation :  423
# Best result in current iteration 109.0897368984105 compared to overall 109.0897368984105
# Generation :  424
# Best result in current iteration 109.0897368984105 compared to overall 109.0897368984105
# Generation :  425
# Best result in current iteration 109.0897368984105 compared to overall 109.0897368984105
# Generation :  426
# Best result in current iteration 109.0897368984105 compared to overall 109.0897368984105
# Generation :  427
# Best result in current iteration 109.0897368984105 compared to overall 109.0897368984105
# Generation :  428
# Best result in current iteration 109.0897368984105 compared to overall 109.0897368984105
# Generation :  429
# Best result in current iteration 109.0897368984105 compared to overall 109.0897368984105
# Generation :  430
# Best result in current iteration 109.0897368984105 compared to overall 109.0897368984105
# Generation :  431
# Best result in current iteration 109.0897368984105 compared to overall 109.0897368984105
# Generation :  432
# Best result in current iteration 109.0897368984105 compared to overall 109.0897368984105
# Generation :  433
# Best result in current iteration 109.0897368984105 compared to overall 109.0897368984105
# Generation :  434
# Best result in current iteration 109.0897368984105 compared to overall 109.0897368984105
# Generation :  435
# Best result in current iteration 109.0897368984105 compared to overall 109.0897368984105
# Generation :  436
# Best result in current iteration 109.0897368984105 compared to overall 109.0897368984105
# Generation :  437
# ...
# Generation :  855
# Best result in current iteration 113.03108503102422 compared to overall 113.03108503102422
# Generation :  856
# Best result in current iteration 113.03108503102422 compared to overall 113.03108503102422
# Generation :  857
# Best result in current iteration 113.03108503102422 compared to overall 113.03108503102422
# Generation :  858
# Best result in current iteration 113.03108503102422 compared to overall 113.03108503102422
# Generation :  859
# Best result in current iteration 113.03108503102422 compared to overall 113.03108503102422
# Generation :  860
# Best result in current iteration 113.03108503102422 compared to overall 113.03108503102422
# Generation :  861
# Best result in current iteration 113.03108503102422 compared to overall 113.03108503102422
# Generation :  862
# Best result in current iteration 113.03108503102422 compared to overall 113.03108503102422
# Generation :  863
# Best result in current iteration 113.03108503102422 compared to overall 113.03108503102422
# Generation :  864
# Best result in current iteration 113.03108503102422 compared to overall 113.03108503102422
# Generation :  865
# Best result in current iteration 113.03108503102422 compared to overall 113.03108503102422
# Generation :  866
# Best result in current iteration 113.03108503102422 compared to overall 113.03108503102422
# Generation :  867
# Best result in current iteration 113.03108503102422 compared to overall 113.03108503102422
# Generation :  868
# Best result in current iteration 113.03108503102422 compared to overall 113.03108503102422
# Generation :  869
# Best result in current iteration 113.03108503102422 compared to overall 113.03108503102422
# Generation :  870
# Best result in current iteration 113.03108503102422 compared to overall 113.03108503102422
# Generation :  871
# Best result in current iteration 113.03108503102422 compared to overall 113.03108503102422
# Generation :  872
# Best result in current iteration 113.03108503102422 compared to overall 113.03108503102422
# Generation :  873
# Best result in current iteration 113.03108503102422 compared to overall 113.03108503102422
# Generation :  874
# Best result in current iteration 113.03108503102422 compared to overall 113.03108503102422
# Generation :  875
# Best result in current iteration 113.03108503102422 compared to overall 113.03108503102422
# Generation :  876
# Best result in current iteration 113.03108503102422 compared to overall 113.03108503102422
# Generation :  877
# Best result in current iteration 113.03108503102422 compared to overall 113.03108503102422
# Generation :  878
# Best result in current iteration 113.03108503102422 compared to overall 113.03108503102422
# Generation :  879
# Best result in current iteration 113.03108503102422 compared to overall 113.03108503102422
# Generation :  880
# Best result in current iteration 113.03108503102422 compared to overall 113.03108503102422
# Generation :  881
# Best result in current iteration 113.03108503102422 compared to overall 113.03108503102422
# Generation :  882
# Best result in current iteration 113.03108503102422 compared to overall 113.03108503102422
# Generation :  883
# Best result in current iteration 113.03108503102422 compared to overall 113.03108503102422
# Generation :  884
# Best result in current iteration 113.03108503102422 compared to overall 113.03108503102422
# Generation :  885
# Best result in current iteration 113.03108503102422 compared to overall 113.03108503102422
# Generation :  886
# Best result in current iteration 113.03108503102422 compared to overall 113.03108503102422
# Generation :  887
# Best result in current iteration 113.03108503102422 compared to overall 113.03108503102422
# Generation :  888
# Best result in current iteration 113.03108503102422 compared to overall 113.03108503102422
# Generation :  889
# Best result in current iteration 113.03108503102422 compared to overall 113.03108503102422
# Generation :  890
# Best result in current iteration 113.03108503102422 compared to overall 113.03108503102422
# Generation :  891
# Best result in current iteration 113.03108503102422 compared to overall 113.03108503102422
# Generation :  892
# Best result in current iteration 113.03108503102422 compared to overall 113.03108503102422
# Generation :  893
# Best result in current iteration 113.03108503102422 compared to overall 113.03108503102422
# Generation :  894
# Best result in current iteration 113.03108503102422 compared to overall 113.03108503102422
# Generation :  895
# Best result in current iteration 113.03108503102422 compared to overall 113.03108503102422
# Generation :  896
# Best result in current iteration 113.03108503102422 compared to overall 113.03108503102422
# Generation :  897
# Best result in current iteration 113.03108503102422 compared to overall 113.03108503102422
# Generation :  898
# Best result in current iteration 113.03108503102422 compared to overall 113.03108503102422
# Generation :  899
# Best result in current iteration 113.03108503102422 compared to overall 113.03108503102422
# Generation :  900
# Best result in current iteration 113.03108503102422 compared to overall 113.03108503102422
# Generation :  901
# Best result in current iteration 113.03108503102422 compared to overall 113.03108503102422
# Generation :  902
# Best result in current iteration 113.03108503102422 compared to overall 113.03108503102422
# Generation :  903
# Best result in current iteration 113.03108503102422 compared to overall 113.03108503102422
# Generation :  904
# Best result in current iteration 113.03108503102422 compared to overall 113.03108503102422
# Generation :  905
# Best result in current iteration 113.03108503102422 compared to overall 113.03108503102422
# Generation :  906
# Best result in current iteration 113.03108503102422 compared to overall 113.03108503102422
# Generation :  907
# Best result in current iteration 113.03108503102422 compared to overall 113.03108503102422
# Generation :  908
# Best result in current iteration 113.03108503102422 compared to overall 113.03108503102422
# Generation :  909
# Best result in current iteration 113.03108503102422 compared to overall 113.03108503102422
# Generation :  910
# Best result in current iteration 113.03108503102422 compared to overall 113.03108503102422
# Generation :  911
# Best result in current iteration 113.03108503102422 compared to overall 113.03108503102422
# Generation :  912
# Best result in current iteration 113.03108503102422 compared to overall 113.03108503102422
# Generation :  913
# Best result in current iteration 113.03108503102422 compared to overall 113.03108503102422
# Generation :  914
# Best result in current iteration 113.03108503102422 compared to overall 113.03108503102422
# Generation :  915
# Best result in current iteration 113.03108503102422 compared to overall 113.03108503102422
# Generation :  916
# Best result in current iteration 113.03108503102422 compared to overall 113.03108503102422
# Generation :  917
# Best result in current iteration 113.03108503102422 compared to overall 113.03108503102422
# Generation :  918
# Best result in current iteration 113.03108503102422 compared to overall 113.03108503102422
# Generation :  919
# Best result in current iteration 113.03108503102422 compared to overall 113.03108503102422
# Generation :  920
# Best result in current iteration 113.03108503102422 compared to overall 113.03108503102422
# Generation :  921
# Best result in current iteration 113.03108503102422 compared to overall 113.03108503102422
# Generation :  922
# Best result in current iteration 113.03108503102422 compared to overall 113.03108503102422
# Generation :  923
# Best result in current iteration 113.03108503102422 compared to overall 113.03108503102422
# Generation :  924
# Best result in current iteration 113.03108503102422 compared to overall 113.03108503102422
# Generation :  925
# Best result in current iteration 113.03108503102422 compared to overall 113.03108503102422
# Generation :  926
# Best result in current iteration 113.03108503102422 compared to overall 113.03108503102422
# Generation :  927
# Best result in current iteration 113.03108503102422 compared to overall 113.03108503102422
# Generation :  928
# Best result in current iteration 113.03108503102422 compared to overall 113.03108503102422
# Generation :  929
# Best result in current iteration 113.03108503102422 compared to overall 113.03108503102422
# Generation :  930
# Best result in current iteration 113.03108503102422 compared to overall 113.03108503102422
# Generation :  931
# Best result in current iteration 113.03108503102422 compared to overall 113.03108503102422
# Generation :  932
# Best result in current iteration 113.03108503102422 compared to overall 113.03108503102422
# Generation :  933
# Best result in current iteration 113.03108503102422 compared to overall 113.03108503102422
# Generation :  934
# Best result in current iteration 113.03108503102422 compared to overall 113.03108503102422
# Generation :  935
# Best result in current iteration 113.03108503102422 compared to overall 113.03108503102422
# Generation :  936
# Best result in current iteration 113.03108503102422 compared to overall 113.03108503102422
# Generation :  937
# Best result in current iteration 113.03108503102422 compared to overall 113.03108503102422
# Generation :  938
# Best result in current iteration 113.03108503102422 compared to overall 113.03108503102422
# Generation :  939
# Best result in current iteration 113.03108503102422 compared to overall 113.03108503102422
# Generation :  940
# Best result in current iteration 113.03108503102422 compared to overall 113.03108503102422
# Generation :  941
# Best result in current iteration 113.03108503102422 compared to overall 113.03108503102422
# Generation :  942
# Best result in current iteration 113.03108503102422 compared to overall 113.03108503102422
# Generation :  943
# Best result in current iteration 113.03108503102422 compared to overall 113.03108503102422
# Generation :  944
# Best result in current iteration 113.03108503102422 compared to overall 113.03108503102422
# Generation :  945
# Best result in current iteration 113.03108503102422 compared to overall 113.03108503102422
# Generation :  946
# Best result in current iteration 113.03108503102422 compared to overall 113.03108503102422
# Generation :  947
# Best result in current iteration 113.03108503102422 compared to overall 113.03108503102422
# Generation :  948
# Best result in current iteration 113.03108503102422 compared to overall 113.03108503102422
# Generation :  949
# Best result in current iteration 113.03108503102422 compared to overall 113.03108503102422
# Generation :  950
# Best result in current iteration 113.03108503102422 compared to overall 113.03108503102422
# Generation :  951
# Best result in current iteration 113.03108503102422 compared to overall 113.03108503102422
# Generation :  952
# Best result in current iteration 113.03108503102422 compared to overall 113.03108503102422
# Generation :  953
# Best result in current iteration 113.03108503102422 compared to overall 113.03108503102422
# Generation :  954
# Best result in current iteration 113.03108503102422 compared to overall 113.03108503102422
# Generation :  955
# Best result in current iteration 113.03108503102422 compared to overall 113.03108503102422
# Generation :  956
# Best result in current iteration 113.03108503102422 compared to overall 113.03108503102422
# Generation :  957
# Best result in current iteration 113.03108503102422 compared to overall 113.03108503102422
# Generation :  958
# Best result in current iteration 113.03108503102422 compared to overall 113.03108503102422
# Generation :  959
# Best result in current iteration 113.03108503102422 compared to overall 113.03108503102422
# Generation :  960
# Best result in current iteration 113.03108503102422 compared to overall 113.03108503102422
# Generation :  961
# Best result in current iteration 113.03108503102422 compared to overall 113.03108503102422
# Generation :  962
# Best result in current iteration 113.03108503102422 compared to overall 113.03108503102422
# Generation :  963
# Best result in current iteration 113.03108503102422 compared to overall 113.03108503102422
# Generation :  964
# Best result in current iteration 113.03108503102422 compared to overall 113.03108503102422
# Generation :  965
# Best result in current iteration 113.03108503102422 compared to overall 113.03108503102422
# Generation :  966
# Best result in current iteration 113.03108503102422 compared to overall 113.03108503102422
# Generation :  967
# Best result in current iteration 113.03108503102422 compared to overall 113.03108503102422
# Generation :  968
# Best result in current iteration 113.03108503102422 compared to overall 113.03108503102422
# Generation :  969
# Best result in current iteration 113.03108503102422 compared to overall 113.03108503102422
# Generation :  970
# Best result in current iteration 113.03108503102422 compared to overall 113.03108503102422
# Generation :  971
# Best result in current iteration 113.03108503102422 compared to overall 113.03108503102422
# Generation :  972
# Best result in current iteration 113.03108503102422 compared to overall 113.03108503102422
# Generation :  973
# Best result in current iteration 113.03108503102422 compared to overall 113.03108503102422
# Generation :  974
# Best result in current iteration 113.03108503102422 compared to overall 113.03108503102422
# Generation :  975
# Best result in current iteration 113.03108503102422 compared to overall 113.03108503102422
# Generation :  976
# Best result in current iteration 113.03108503102422 compared to overall 113.03108503102422
# Generation :  977
# Best result in current iteration 113.03108503102422 compared to overall 113.03108503102422
# Generation :  978
# Best result in current iteration 113.03108503102422 compared to overall 113.03108503102422
# Generation :  979
# Best result in current iteration 113.03108503102422 compared to overall 113.03108503102422
# Generation :  980
# Best result in current iteration 113.03108503102422 compared to overall 113.03108503102422
# Generation :  981
# Best result in current iteration 113.03108503102422 compared to overall 113.03108503102422
# Generation :  982
# Best result in current iteration 113.03108503102422 compared to overall 113.03108503102422
# Generation :  983
# Best result in current iteration 113.03108503102422 compared to overall 113.03108503102422
# Generation :  984
# Best result in current iteration 113.03108503102422 compared to overall 113.03108503102422
# Generation :  985
# Best result in current iteration 113.03108503102422 compared to overall 113.03108503102422
# Generation :  986
# Best result in current iteration 113.03108503102422 compared to overall 113.03108503102422
# Generation :  987
# Best result in current iteration 113.03108503102422 compared to overall 113.03108503102422
# Generation :  988
# Best result in current iteration 113.03108503102422 compared to overall 113.03108503102422
# Generation :  989
# Best result in current iteration 113.03108503102422 compared to overall 113.03108503102422
# Generation :  990
# Best result in current iteration 113.03108503102422 compared to overall 113.03108503102422
# Generation :  991
# Best result in current iteration 113.03108503102422 compared to overall 113.03108503102422
# Generation :  992
# Best result in current iteration 113.03108503102422 compared to overall 113.03108503102422
# Generation :  993
# Best result in current iteration 113.03108503102422 compared to overall 113.03108503102422
# Generation :  994
# Best result in current iteration 113.03108503102422 compared to overall 113.03108503102422
# Generation :  995
# Best result in current iteration 113.03108503102422 compared to overall 113.03108503102422
# Generation :  996
# Best result in current iteration 113.03108503102422 compared to overall 113.03108503102422
# Generation :  997
# Best result in current iteration 113.03108503102422 compared to overall 113.03108503102422
# Generation :  998
# Best result in current iteration 113.03108503102422 compared to overall 113.03108503102422
# Generation :  999
# Best result in current iteration 113.03108503102422 compared to overall 113.03108503102422
# Best solution :  [ 3.94343725  3.90140664 -3.85211265  3.98738294  3.78605302 -2.93155615]
# Best solution fitness :  113.03108503102422

# %% [markdown]
# Let's see how our GA performed!

# %%
import pylab as plt
import seaborn as sns
sns.set_context("talk", font_scale=1.5, rc={"lines.linewidth": 2.5})

# %matplotlib inline
plt.figure(figsize=(12,12))
plt.plot(best_outputs,'-o', lw=3, ms=20, label='from scratch')
plt.xlabel("Iteration")
plt.ylabel("Fitness")
plt.show()
# Out:
# Text(0.5, 0, 'Iteration')
# Text(0, 0.5, 'Fitness')

# %%
# %matplotlib inline
plt.figure(figsize=(12,12))
plt.plot(120-np.array(best_outputs),'-o', lw=3, ms=20, label='from scratch')
plt.xlabel("Iteration")
plt.ylabel("Fitness")
plt.show()
# Out:
# Text(0.5, 0, 'Iteration')
# Text(0, 0.5, 'Fitness')

# %% [markdown]
# ## Yay! Looks like it works, although not very well. Explore and see what can be improved
#
# Acknowledgement: Content from this notebook is drawn from Ahmed Gad's GA implementation, found at his [Github](https://github.com/ahmedfgad/GeneticAlgorithmPython).

# %% [markdown]
# ## We are not done yet!
#
# To have a black box optimizer, we need to wrap all this functionality into something that's abstracted away from the end user (in this case you). What does that mean? Think about:
# - Change in the cost function (Knapsack, Rastrigin)
#     - Function changes (and along with it discontinuities, ill-conditioning, non-separability...)
#     - Dimensionality of the problem changes (n=1,...,100,...1000?)
#     - Other concerns
# - Change in the encoding (reals, bitvectors)
# - ...
#
# That is to say, write something well once and keep on reusing it---functions! Also store associated variables---classes!

# %% [markdown]
# ## HW : Wrap this up in a GA class and reuse it in your applications (Project 1)

# %%
a = np.sin

# %%
a
# Out:
# <ufunc 'sin'>

# %%
def fitness(my_func):
    return my_func(2.0)
    
fitness(a)
# Out:
# 0.9092974268256817
